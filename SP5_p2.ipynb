# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
ds= pd.read_csv("/content/drive/MyDrive/SP5_p2/test.csv")

# %%
ds
# Out:
#        budget                                 company  ...            writer  year
# 0     8000000           Columbia Pictures Corporation  ...      Stephen King  1986
# 1     6000000                      Paramount Pictures  ...       John Hughes  1986
# 2    15000000                      Paramount Pictures  ...          Jim Cash  1986
# 3    18500000  Twentieth Century Fox Film Corporation  ...     James Cameron  1986
# 4     9000000                    Walt Disney Pictures  ...     Mark H. Baker  1986
# ..        ...                                     ...  ...               ...   ...
# 794         0                      Paramount Pictures  ...     Steven Greene  1989
# 795         0                Gary Sherman Productions  ...      Gary Sherman  1989
# 796   1500000   Incorporated Television Company (ITC)  ...  Carolyn Lefcourt  1989
# 797         0           Columbia Pictures Corporation  ...     Wesley Strick  1989
# ...

# %%
ds.drop(labels=['rating'],axis=1)
# Out:
#                                                   budget  ...  year
# company                                country            ...
# Columbia Pictures Corporation          USA       8000000  ...  1986
# Paramount Pictures                     USA       6000000  ...  1986
#                                        USA      15000000  ...  1986
# Twentieth Century Fox Film Corporation USA      18500000  ...  1986
# Walt Disney Pictures                   USA       9000000  ...  1986
# ...                                                  ...  ...   ...
# Paramount Pictures                     Canada          0  ...  1989
# Gary Sherman Productions               USA             0  ...  1989
# Incorporated Television Company (ITC)  UK        1500000  ...  1989
# Columbia Pictures Corporation          USA             0  ...  1989
# Golan-Globus Productions               USA             0  ...  1989
#
# [799 rows x 12 columns]

# %%
ds.drop(index= [785,786,789,791,792,793,794,795,797,798])
# Out:
#        budget                                 company  ...            writer  year
# 0     8000000           Columbia Pictures Corporation  ...      Stephen King  1986
# 1     6000000                      Paramount Pictures  ...       John Hughes  1986
# 2    15000000                      Paramount Pictures  ...          Jim Cash  1986
# 3    18500000  Twentieth Century Fox Film Corporation  ...     James Cameron  1986
# 4     9000000                    Walt Disney Pictures  ...     Mark H. Baker  1986
# ..        ...                                     ...  ...               ...   ...
# 784   3000000                      American Playhouse  ...       Craig Lucas  1989
# 787   4000000   Incorporated Television Company (ITC)  ...         John Dahl  1989
# 788   2300000              Lorimar Film Entertainment  ...     Lloyd Kaufman  1989
# 790   2500000                       Larco Productions  ...       Larry Cohen  1989
# ...

# %%
ds= pd.read_csv("/content/drive/MyDrive/SP5_p2/test.csv",index_col=['company','country',])
ds
# Out:
#                                                   budget  ...  year
# company                                country            ...
# Columbia Pictures Corporation          USA       8000000  ...  1986
# Paramount Pictures                     USA       6000000  ...  1986
#                                        USA      15000000  ...  1986
# Twentieth Century Fox Film Corporation USA      18500000  ...  1986
# Walt Disney Pictures                   USA       9000000  ...  1986
# ...                                                  ...  ...   ...
# Paramount Pictures                     Canada          0  ...  1989
# Gary Sherman Productions               USA             0  ...  1989
# Incorporated Television Company (ITC)  UK        1500000  ...  1989
# Columbia Pictures Corporation          USA             0  ...  1989
# Golan-Globus Productions               USA             0  ...  1989
#
# [799 rows x 13 columns]

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 799 entries, 0 to 798
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   budget    799 non-null    int64
#  1   company   799 non-null    object
#  2   country   799 non-null    object
#  3   director  799 non-null    object
#  4   genre     799 non-null    object
#  5   gross     799 non-null    int64
#  6   name      799 non-null    object
#  7   rating    799 non-null    object
#  8   released  799 non-null    object
#  9   runtime   799 non-null    int64
#  10  score     799 non-null    float64
#  11  star      799 non-null    object
#  12  votes     799 non-null    int64
#  13  writer    799 non-null    object
#  14  year      799 non-null    int64
# dtypes: float64(1), int64(5), object(9)
# memory usage: 93.8+ KB

# %%
ds.describe()
# Out:
#              budget         gross  ...          votes         year
# count  7.990000e+02  7.990000e+02  ...     799.000000   799.000000
# mean   6.606348e+06  1.754874e+07  ...   25149.927409  1987.350438
# std    1.022740e+07  2.933887e+07  ...   60300.473971     1.063096
# min    0.000000e+00  3.151000e+03  ...     103.000000  1986.000000
# 25%    0.000000e+00  1.335788e+06  ...    1979.000000  1986.000000
# 50%    0.000000e+00  5.923044e+06  ...    5638.000000  1987.000000
# 75%    1.125000e+07  1.932103e+07  ...   22476.500000  1988.000000
# max    7.000000e+07  2.511889e+08  ...  647000.000000  1989.000000
#
# [8 rows x 6 columns]

# %%
ds[ds['budget']>15000000]
# Out:
#                                                   budget  ...  year
# company                                country            ...
# Twentieth Century Fox Film Corporation USA      18500000  ...  1986
# Henson Associates (HA)                 UK       25000000  ...  1986
# Thorn EMI Screen Entertainment         UK       16000000  ...  1986
# Twentieth Century Fox Film Corporation USA      25000000  ...  1986
# Producers Sales Organization (PSO)     USA      17000000  ...  1986
# ...                                                  ...  ...   ...
# Malpaso Productions                    USA      19000000  ...  1989
# Amblin Entertainment                   USA      19000000  ...  1989
# Orion Pictures                         USA      18000000  ...  1989
# Paramount Pictures                     USA      18000000  ...  1989
# Warner Bros.                           USA      18000000  ...  1989
#
# [137 rows x 13 columns]

# %%
sns.countplot(x='runtime', data = ds)
ds['runtime'].value_counts()
# Out:
# 100    66
# 90     36
# 97     35
# 93     33
# 96     32
#        ..
# 135     1
# 134     1
# 131     1
# 129     1
# 69      1
# Name: runtime, Length: 79, dtype: int64

# %%
sns.lmplot(x='genre', y='votes', data = ds)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-114-246469b8afd7> in <module>()
# ----> 1 sns.lmplot(x='genre', y='votes', data = ds)
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, size)
# ...

# %%
ds["year"].hist()
ds['year'].value_counts()
# Out:
# 1988    220
# 1986    220
# 1987    219
# 1989    140
# Name: year, dtype: int64

# %%
ds["budget"].hist()

# %%
sns.lmplot(x= 'gross', y ='year',data = ds)

# %%
ds['votes'].plot()

# %%
sns.lmplot(x= 'runtime', y ='score',data = ds)
